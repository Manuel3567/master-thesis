# %%
from analysis.datasets import load_merra
import matplotlib.pyplot as plt
import seaborn as sns
from analysis.explorative_analysis import *

# %%
from datetime import datetime, timedelta

# %%
start_date = datetime(2017,1,1)
#.strftime('%Y-%m-%d')

# %%
start_date + timedelta(days=1)
# Out:
# datetime.datetime(2017, 1, 2, 0, 0)

# %%
date = datetime(2017,1,1)
while date.strftime('%Y-%m-%d') != '2024-09-01':
    try:
        load_merra(start_date = date.strftime('%Y-%m-%d'), end_date=date.strftime('%Y-%m-%d'))
    except Exception:
        print(date.strftime('%Y-%m-%d'))
    date += timedelta(days=1)

# %%
df = load_merra(start_date= '2022-01-01', end_date= '2022-12-31')

# %%
explorative_analysis(df)
# Out:
# Summary statistics for time frame: 2022-01-01 - 2022-12-31
# First 5 rows of the dataframe:
#                       lat     lon  layer_height (m)  pressure (Pa)  \
# time
# 2022-01-01 00:00:00  53.0  13.125         62.945030  100817.835938
# 2022-01-01 01:00:00  53.0  13.125         62.974159  100866.054688
# 2022-01-01 02:00:00  53.0  13.125         62.998837  100931.578125
# 2022-01-01 03:00:00  53.0  13.125         63.007450  100996.882812
# 2022-01-01 04:00:00  53.0  13.125         62.992607  101041.179688
#
#                      specific_humidity (1)  wind_speed (m/s)  \
# time
# 2022-01-01 00:00:00               0.007356         11.123240
# 2022-01-01 01:00:00               0.007379         11.657583
# 2022-01-01 02:00:00               0.007426         11.427160
# 2022-01-01 03:00:00               0.007452         11.504524
# 2022-01-01 04:00:00               0.007421         10.988786
#
#                      air_temperature (K)
# time
# ...

# %%
weather_2022['wind_speed (m/s)'].hist(bins=20, figsize=(10, 6))
plt.title('Histogram of Wind Speed (m/s)')
plt.xlabel('Wind Speed (m/s)')
plt.ylabel('Frequency')
plt.show()

# %%
plt.scatter(weather_2022['wind_speed (m/s)'], weather_2022['air_temperature (K)'])
plt.xlabel('Wind Speed (m/s)')
plt.ylabel('air temperature (K)')
# Out:
# Text(0, 0.5, 'air temperature (K)')

# %%
df.head()
# Out:
#                       lat     lon  layer_height (m)  pressure (Pa)  \
# time
# 2023-08-06 00:00:00  53.0  13.125         64.159569  100136.226562
# 2023-08-06 01:00:00  53.0  13.125         64.141228  100074.671875
# 2023-08-06 02:00:00  53.0  13.125         64.135986  100010.179688
# 2023-08-06 03:00:00  53.0  13.125         64.113350   99932.750000
# 2023-08-06 04:00:00  53.0  13.125         64.120392   99908.937500
#
#                      specific_humidity (1)  wind_speed (m/s)  \
# time
# 2023-08-06 00:00:00               0.010264          5.381614
# 2023-08-06 01:00:00               0.010297          4.843354
# 2023-08-06 02:00:00               0.010271          4.521528
# 2023-08-06 03:00:00               0.010222          3.724590
# 2023-08-06 04:00:00               0.010187          3.169215
#
#                      air_temperature (K)
# time
# 2023-08-06 00:00:00           288.256989
# 2023-08-06 01:00:00           288.169312
# 2023-08-06 02:00:00           288.150909
# ...

# %%
# currently not working for end_date= '2024-01-03'


#from analysis.datasets import load_merra
#df = load_merra(end_date= '2024-01-03')
#df.tail()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Manuel\Documents\Masterarbeit\.venv\lib\site-packages\xarray\backends\file_manager.py:211, in CachingFileManager._acquire_with_cache_info(self, needs_lock)
#     210 try:
# --> 211     file = self._cache[self._key]
#     212 except KeyError:
#
# File c:\Users\Manuel\Documents\Masterarbeit\.venv\lib\site-packages\xarray\backends\lru_cache.py:56, in LRUCache.__getitem__(self, key)
#      55 with self._lock:
# ---> 56     value = self._cache[key]
#      57     self._cache.move_to_end(key)
#
# KeyError: [<class 'netCDF4._netCDF4.Dataset'>, ('c:\\Users\\Manuel\\Documents\\Masterarbeit\\data\\raw\\merra2\\merra2_13.125_53.0_2017_09_21.nc',), 'r', (('clobber', True), ('diskless', False), ('format', 'NETCDF4'), ('persist', False)), '23062e92-68a9-4388-a718-e31777af0a21']
#
# ...

# %%
import xarray as xr

# %%
df['wind_speed (m/s)'].plot.hist(bins=40, edgecolor='black', title='Frequency Distribution')
# Out:
# <Axes: title={'center': 'Frequency Distribution'}, ylabel='Frequency'>

# %%
# Subtract 273 from the 'wind_speed (m/s)' column
df['air_temperature (K)'] = df['air_temperature (K)'] - 273.15

# Plot the updated frequency distribution
df['air_temperature (K)'].plot.hist(bins=40, edgecolor='black', title='Frequency Distribution')
# Out:
# <Axes: title={'center': 'Frequency Distribution'}, ylabel='Frequency'>

# %%
df['pressure (Pa)'].plot.hist(bins=40, edgecolor='black', title='Frequency Distribution')
# Out:
# <Axes: title={'center': 'Frequency Distribution'}, ylabel='Frequency'>

# %%
df['layer_height (m)'].plot.hist(bins=40, edgecolor='black', title='Frequency Distribution')
# Out:
# <Axes: title={'center': 'Frequency Distribution'}, ylabel='Frequency'>

# %%
ds.sel(lat=53, lon=13, method="nearest").to_dataframe()
# Out:
#                           HLML      QLML   SPEEDLML             PS  \
# time
# 2017-01-01 00:00:00  60.805107  0.003796   8.995690  101443.648438
# 2017-01-01 01:00:00  60.838306  0.003819   9.255361  101366.218750
# 2017-01-01 02:00:00  60.816212  0.003821   8.864300  101284.882812
# 2017-01-01 03:00:00  60.809200  0.003813   9.169664  101209.945312
# 2017-01-01 04:00:00  60.808372  0.003790   9.174767  101141.156250
# 2017-01-01 05:00:00  60.763233  0.003730   9.578008  101075.656250
# 2017-01-01 06:00:00  60.686535  0.003626   9.866473  101022.109375
# 2017-01-01 07:00:00  60.583023  0.003481  10.024042  100973.984375
# 2017-01-01 08:00:00  60.479027  0.003322   9.967559  100952.242188
# 2017-01-01 09:00:00  60.505615  0.003247   9.764323  100929.234375
# 2017-01-01 10:00:00  60.613079  0.003261   9.088619  100905.484375
# 2017-01-01 11:00:00  60.751446  0.003297   8.966830  100851.320312
# 2017-01-01 12:00:00  60.861473  0.003359   8.669847  100793.476562
# ...
